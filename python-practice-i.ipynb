# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
x,y = input().split()
print(x,'\n',y)
# Out:
#  1 2
# 1
#  2

# %%
l = "Python in 15 Videos | HackerRank Tutorial | Lists, Strings, If else, Split | Hindi Tutorial Code"
f = l.find('else')
print(f)
for i in range(len(l)):
    print(i,l[i])
# Out:
# 63
# 0 P
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n
# 6
# 7 i
# 8 n
# 9
# 10 1
# 11 5
# 12
# 13 V
# 14 i
# 15 d
# 16 e
# 17 o
# 18 s
# 19
# 20 |
# 21
# 22 H
# 23 a
# 24 c
# 25 k
# 26 e
# 27 r
# 28 R
# 29 a
# 30 n
# 31 k
# 32
# 33 T
# 34 u
# 35 t
# 36 o
# 37 r
# 38 i
# 39 a
# 40 l
# 41
# 42 |
# 43
# 44 L
# 45 i
# 46 s
# 47 t
# 48 s
# 49 ,
# 50
# 51 S
# 52 t
# 53 r
# 54 i
# 55 n
# 56 g
# 57 s
# 58 ,
# 59
# 60 I
# 61 f
# 62
# 63 e
# 64 l
# 65 s
# 66 e
# 67 ,
# 68
# 69 S
# 70 p
# 71 l
# 72 i
# 73 t
# 74
# 75 |
# 76
# 77 H
# 78 i
# 79 n
# 80 d
# 81 i
# 82
# 83 T
# 84 u
# 85 t
# 86 o
# 87 r
# 88 i
# 89 a
# 90 l
# 91
# 92 C
# 93 o
# 94 d
# 95 e

# %%
def insertIntoList(L,x,y):
        L.insert(x,y)
N = int(input())
L = []
for i in range(N):
        query = input()
        if (query.find("insert")>=0):
                a = query[7:]
                x,y = a.split()
                x = int(x)
                y = int(y)
                insertIntoList(L,x,y)
        
        elif (query.find("remove")>=0):
                 b = query[7:]
                 b = int(b)
                 L.remove(b)


        elif (query.find("print")>=0):
                 print(L)
        
        elif (query.find("append")>=0):
                 c = query[7:]
                 c = int(c)
                 L.append(c)

        elif (query.find("sort")>=0):
                L.sort()

        elif (query.find("pop")>=0):
                L.pop(-1)

        elif (query.find("reverse")>=0):
                L.reverse()

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        m = 0
        m += 1
    print(m)
    if (n>=1 & n<=150):
        print(m)

# %%
d = {'datta':90, 'vikas':80, 'anu': 75}
del d['vikas']
lk = d.keys()
lv = d.values()
d['om']= 56
print(d['datta'])

if ('datta'in d):
    print("Yes")



print(d)

# %%
for i in d:
    print(i ,':', d[i])

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
x = [1,-1,-1,1,1] 
y = [1,1,-1,-1,1]
plt.plot(x,y)
plt.show()

# %% [markdown]
# # **Python Practice                                                              13 July 2024**

# %% [markdown]
# * **Python introduced in 1989**
# * **Guido Van Rossum (Dutch Programmer)**
# * **Comedy Series (Monty python flying circus)**

# %% [markdown]
# **Features of Python**
# * Open source (free to use)
# * Interpreted Programming Language
# * Rich Libraries: Numpy, Pandas, Tensorflow, Flask, Django
# * Automatic Memory management.
# * Used in ML, AI, DS, IOT, Hacking, Games etc.

# %% [markdown]
# **Data Type**
# 1. **Numeric Datatype :** int, float, complex
# 2. **Sequence Datatype :** string, list, tuple
# 3. **Collection Datatype :** set, dict
# 4. **Boolean :** true, false (0,1)

# %% [markdown]
# * **Number Conversion**

# %% [markdown]
# **Python Function**
# * int()
# * float()
# * complex()
# * bin()
# * oct()
# * hex()

# %%
number = int(input("Enter the number : "))
point_number = float(number)
binary = bin(number )
hexa_decimal = hex(number)
complex_number = complex(number)
octal_number = oct(number)

print(f"Your Number : {number} \n Float conversion : {point_number} \n Binary Conversion : {binary} \n Hexa-decimal Conversion : {hexa_decimal} \n Complex Number Conversion : {complex_number} \n Ocatal Number Conversion : {octal_number}")
# Out:
# Enter the number :  24
# Your Number : 24
#  Float conversion : 24.0
#  Binary Conversion : 0b11000
#  Hexa-decimal Conversion : 0x18
#  Complex Number Conversion : (24+0j)
#  Ocatal Number Conversion : 0o30

# %% [markdown]
# * **Arithmetic Operator**

# %%
n1 = int(input("Enter the 1st number : "))
n2 = int(input("Enter the 2nd number : "))
print(f"Addition : {n1 + n2} \n Subtraction : {n1 - n2} \n Division : {n1 / n2} \n Modulo to get remainder : {n1 % n2} \n Floor division : {n1 // n2} \n Multiplication : {n1 * n2} \n Power of {n1} raise to {n2} : {n1 ** n2}")
# Out:
# Enter the 1st number :  28
# Enter the 2nd number :  3
# Addition : 31
#  Subtraction : 25
#  Division : 9.333333333333334
#  Modulo to get remainder : 1
#  Floor division : 9
#  Multiplication : 84
#  Power of 28 raise to 3 : 21952

# %% [markdown]
# * **F String Concept**

# %%
name = "Dattatraya"
age = 23

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Dattatraya and I am 23 years old.

# %% [markdown]
# **Formatting string using Escape sequence**
# * \n - Breaks the line
# * \t - Add horizonatal tab
# * \\ - To print backslash
# * \\' - To print single quote (')
# * \\" - To print double quote (")

# %% [markdown]
# **Operators used for string, list, tuple**
# * concatenation(+)
# * repetition(*)
# * slice []
# * range slice [ : ]
# * in membership
# * not in membership

# %%
first_name = "Datta"
surname = "Mundhe"
print(f"Concatenation : {first_name + surname} \n Repetition : {first_name * 5} \n Slice  : {surname[4]} \n Range slice : {surname[0:3]} \n in membership : {'h' in surname} \n not in membership : { 'M' not in surname}")
# Out:
# Concatenation : DattaMundhe
#  Repetition : DattaDattaDattaDattaDatta
#  Slice  : h
#  Range slice : Mun
#  in membership : True
#  not in membership : False

# %%
yr = int(input("Enter year to check : "))

if yr % 4 == 0:
  if yr % 100 == 0:
    if yr % 400 == 0:
      print(f"{yr} is Leap Year ")
    else:
      print(f"{yr} Not Leap Year ")
  else:
    print(f"{yr} is Leap Year ")
else:
  print(f"{yr} Not Leap Year ")
# Out:
# Enter year to check :  2001
# 2001 Not Leap Year

# %%
x = 1
while(x<=10) :
    print(x*23)
    x+=1
# Out:
# 23
# 46
# 69
# 92
# 115
# 138
# 161
# 184
# 207
# 230
